# %% [markdown]
# # This notebook will walk through creating an animated chloropleth map of PA using COVID data from Johns Hopkins

# %%
# Import libraries
import numpy as np 
import pandas as pd 
import plotly as py
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Read in US data
df = pd.read_csv("D:/GitHub/AI/DataScience/Visualization/COVID/data/time_series_covid19_confirmed_US.csv")

# %%
df.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 4/8/20  4/9/20  4/10/20  4/11/20  4/12/20  4/13/20  \
# 0 -14.2710 -170.1320  ...      0       0        0        0        0        0
# 1  13.4443  144.7937  ...    121     128      130      133      133      133
# 2  15.0979  145.6739  ...     11      11       11       11       11       11
# 3  18.2208  -66.5901  ...    620     683      725      788      897      903
# 4  18.3358  -64.8963  ...     45      45       50       51       51       51
#
# ...

# %%
df_pa = df[(df.Province_State == "Pennsylvania")]

# %%
df_pa.head()
# Out:
#              UID iso2 iso3  code3     FIPS Admin2 Province_State  \
# 2249  84042001.0   US  USA    840  42001.0  Adams   Pennsylvania
#
#      Country_Region        Lat      Long_  ... 4/6/20  4/7/20  4/8/20  4/9/20  \
# 2249             US  39.871404 -77.216103  ...     25      28      33      38
#
#       4/10/20  4/11/20  4/12/20  4/13/20  4/14/20  4/15/20
# 2249       43       44       48       56       63       64
#
# [1 rows x 96 columns]

# %%
df_pa.dtypes
# Out:
# UID        float64
# iso2        object
# iso3        object
# code3        int64
# FIPS       float64
#             ...
# 4/11/20      int64
# 4/12/20      int64
# 4/13/20      int64
# 4/14/20      int64
# 4/15/20      int64
# Length: 96, dtype: object

# %%
#Creating the visualization
fig = px.choropleth(df, 
                    locations="Province_State", 
                    locationmode = "State names",
                    color="Confirmed", 
                    hover_name="Province_State", 
                    animation_frame="Date"
                   )
fig.update_layout(
    title_text = 'PA Spread of Coronavirus',
    title_x = 0.5,
    geo=dict(
        showframe = False,
        showcoastlines = False,
    ))
    
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-5038e2fd976e> in <module>
#       5                     color="Confirmed",
#       6                     hover_name="Province_State",
# ----> 7                     animation_frame="Date"
#       8                    )
#       9 fig.update_layout(
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_chart_types.py in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, title, template, width, height)
#     879             geojson=geojson
#     880             if not hasattr(geojson, "__geo_interface__")  # for geopandas
# ...

# %%
using GLMakie
using GraphMakie
using Graphs
g = complete_graph(10)
graphplot(g)
# Out:
# FigureAxisPlot()

# %%
Pkg.add JSServe
# Out:
# syntax: extra token "JSServe" after end of expression
#
# Stacktrace:
#  [1] top-level scope
#    @ In[4]:1
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1116
